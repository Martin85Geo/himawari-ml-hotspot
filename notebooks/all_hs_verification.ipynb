# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import glob
import geopandas
import numpy as np
import cartopy.feature as cfeature
from cartopy import crs as ccrs
from shapely import geometry
from datetime import datetime

# %%
hs_df = geopandas.GeoDataFrame()

for day in range(1, 32):
    date_object = datetime(2019, 7, day)
    file = './output/LATE_2km_SG00_hotspot_grid_' + date_object.strftime("%Y%m%d") + '.geojson'
    temp = geopandas.read_file(file)
    temp['sat_date'] = date_object.strftime("%d/%m/%Y")
    hs_df = hs_df.append(temp)

# %%
hs_df.crs = {'init': 'epsg:3857'}
hs_df['id_grid'] = hs_df.index

# %%
clip_area = geopandas.read_file('./verification/July_updated.shp')
clip_area = clip_area.to_crs({'init': 'epsg:3857'})

# %%
truth_df = pd.read_csv('./verification/july_ground_truth_2019.csv')

# %%
truth_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
truth_gdf = geopandas.GeoDataFrame(truth_df, geometry=geopandas.points_from_xy(truth_df.lon, truth_df.lat))

# %%
truth_gdf.crs = {'init' :'epsg:4326'}
truth_gdf = truth_gdf.to_crs({'init': 'epsg:3857'})

# %%
truth_gdf_b500 = truth_gdf.buffer(1500)

# %%
truth_gdf.geometry = truth_gdf_b500

# %%
hs_df_clipped = geopandas.overlay(clip_area, hs_df, how='intersection')

# %%
hs_df_clipped.drop(columns=['id'], inplace=True)
hs_df_clipped.head()
# Out:
#      weight  geo_weight  polar_weight  adj_weight    sat_date  id_grid  \
# 0  0.066250    0.000000       0.06625    0.257391  11/07/2019     5773
# 1  0.474902    0.254902       0.22000    0.689131  26/07/2019     2921
# 2  0.039216    0.039216       0.00000    0.198030  31/07/2019     3977
# 3  0.178431    0.078431       0.10000    0.422411  29/07/2019     2613
# 4  0.623358    0.019608       0.60375    0.789530  14/07/2019     2238
#
#                                             geometry
# 0  POLYGON ((11335976.873 -13195.474, 11337976.87...
# 1  POLYGON ((11335976.873 -13195.474, 11337976.87...
# 2  POLYGON ((11335976.873 -13195.474, 11337976.87...
# 3  POLYGON ((11320593.302 -15195.474, 11320603.45...
# 4  POLYGON ((11320593.302 -15195.474, 11320603.45...

# %%
truth_gdf['id_truth'] = truth_gdf.index
truth_gdf.head()
# Out:
#    datestamp       lat         lon                     period  \
# 0  20/7/2019 -0.126831  101.696714  0 days 00:00:00.000000000
# 1  20/7/2019 -0.137187  101.699419  0 days 00:00:00.000000000
# 2  20/7/2019 -0.124976  101.709003  0 days 00:00:00.000000000
# 3  25/7/2019 -0.127913  101.708152  0 days 00:00:00.000000000
# 4  25/7/2019 -0.132241  101.698337  0 days 00:00:00.000000000
#
#                                             geometry        end_date  \
# 0  POLYGON ((11322326.418 -14118.750, 11322319.19...  20/7/2019 0:00
# 1  POLYGON ((11322627.537 -15271.632, 11322620.31...  20/7/2019 0:00
# 2  POLYGON ((11323694.379 -13912.263, 11323687.15...  20/7/2019 0:00
# 3  POLYGON ((11323599.746 -14239.200, 11323592.52...  25/7/2019 0:00
# 4  POLYGON ((11322507.089 -14721.002, 11322499.86...  25/7/2019 0:00
#
#        start_date  id_truth
# 0  20/7/2019 0:00         0
# 1  20/7/2019 0:00         1
# 2  20/7/2019 0:00         2
# 3  25/7/2019 0:00         3
# 4  25/7/2019 0:00         4

# %%
overlaid_gdf_ungrp = geopandas.overlay(truth_gdf, hs_df_clipped, how='union')

# %%
overlaid_gdf_ungrp.head()
# Out:
#    datestamp       lat         lon                     period        end_date  \
# 0  20/7/2019 -0.126831  101.696714  0 days 00:00:00.000000000  20/7/2019 0:00
# 1  20/7/2019 -0.124976  101.709003  0 days 00:00:00.000000000  20/7/2019 0:00
# 2  25/7/2019 -0.127913  101.708152  0 days 00:00:00.000000000  25/7/2019 0:00
# 3  20/7/2019 -0.126831  101.696714  0 days 00:00:00.000000000  20/7/2019 0:00
# 4  20/7/2019 -0.124976  101.709003  0 days 00:00:00.000000000  20/7/2019 0:00
#
#        start_date  id_truth    weight  geo_weight  polar_weight  adj_weight  \
# 0  20/7/2019 0:00       0.0  0.109804    0.009804           0.1    0.331367
# 1  20/7/2019 0:00       2.0  0.109804    0.009804           0.1    0.331367
# 2  25/7/2019 0:00       3.0  0.109804    0.009804           0.1    0.331367
# 3  20/7/2019 0:00       0.0  0.186275    0.186275           0.0    0.431595
# 4  20/7/2019 0:00       2.0  0.186275    0.186275           0.0    0.431595
#
#      sat_date  id_grid                                           geometry
# 0  14/07/2019   2235.0  POLYGON ((11320606.290 -12636.816, 11320679.39...
# 1  14/07/2019   2235.0  POLYGON ((11320877.307 -13195.474, 11320947.17...
# 2  14/07/2019   2235.0  POLYGON ((11321023.737 -13195.474, 11321039.08...
# 3  12/07/2019   4234.0  POLYGON ((11320606.290 -12636.816, 11320679.39...
# 4  12/07/2019   4234.0  POLYGON ((11320877.307 -13195.474, 11320947.17...

# %%
overlaid_gdf = overlaid_gdf_ungrp.sort_values(by=['adj_weight']).groupby(['id_grid', 'sat_date']).last()

# %%
#overlaid_gdf_ungrp.shape
overlaid_gdf_ungrp.loc[overlaid_gdf_ungrp['sat_date'] == '25/07/2019']
overlaid_gdf
# Out:
#                        datestamp       lat         lon  \
# id_grid sat_date
# 1271.0  01/07/2019           NaN       NaN         NaN
# 1272.0  01/07/2019           NaN       NaN         NaN
# 1273.0  01/07/2019           NaN       NaN         NaN
# 1274.0  01/07/2019           NaN       NaN         NaN
# 1278.0  01/07/2019           NaN       NaN         NaN
# 1279.0  01/07/2019           NaN       NaN         NaN
# 1282.0  01/07/2019           NaN       NaN         NaN
# 1307.0  01/07/2019           NaN       NaN         NaN
# 1323.0  01/07/2019           NaN       NaN         NaN
# 1324.0  01/07/2019           NaN       NaN         NaN
# 1336.0  01/07/2019           NaN       NaN         NaN
# 1337.0  01/07/2019           NaN       NaN         NaN
# 1343.0  01/07/2019     16/7/2019  0.164093  109.250019
# 1344.0  01/07/2019           NaN       NaN         NaN
# 1345.0  01/07/2019           NaN       NaN         NaN
# 1346.0  01/07/2019           NaN       NaN         NaN
# 1347.0  01/07/2019           NaN       NaN         NaN
# 1348.0  01/07/2019           NaN       NaN         NaN
# 1349.0  01/07/2019           NaN       NaN         NaN
# 1350.0  01/07/2019           NaN       NaN         NaN
# 1351.0  01/07/2019           NaN       NaN         NaN
# 1352.0  01/07/2019           NaN       NaN         NaN
# 1353.0  01/07/2019           NaN       NaN         NaN
# 1354.0  01/07/2019           NaN       NaN         NaN
# 1355.0  01/07/2019           NaN       NaN         NaN
# 1356.0  01/07/2019           NaN       NaN         NaN
# 1357.0  01/07/2019           NaN       NaN         NaN
# 1358.0  01/07/2019           NaN       NaN         NaN
# 1359.0  01/07/2019           NaN       NaN         NaN
# 1360.0  01/07/2019           NaN       NaN         NaN
# ...                          ...       ...         ...
# 6259.0  11/07/2019           NaN       NaN         NaN
# 6260.0  11/07/2019           NaN       NaN         NaN
# 6261.0  11/07/2019           NaN       NaN         NaN
# 6262.0  11/07/2019           NaN       NaN         NaN
# 6263.0  11/07/2019           NaN       NaN         NaN
# 6264.0  11/07/2019           NaN       NaN         NaN
# 6265.0  11/07/2019           NaN       NaN         NaN
# 6266.0  11/07/2019           NaN       NaN         NaN
# 6267.0  11/07/2019           NaN       NaN         NaN
# 6268.0  11/07/2019           NaN       NaN         NaN
# 6269.0  11/07/2019           NaN       NaN         NaN
# 6270.0  11/07/2019           NaN       NaN         NaN
# 6271.0  11/07/2019           NaN       NaN         NaN
# 6272.0  11/07/2019           NaN       NaN         NaN
# 6273.0  11/07/2019           NaN       NaN         NaN
# 6274.0  11/07/2019           NaN       NaN         NaN
# 6275.0  11/07/2019           NaN       NaN         NaN
# 6276.0  11/07/2019           NaN       NaN         NaN
# 6277.0  11/07/2019           NaN       NaN         NaN
# 6278.0  11/07/2019           NaN       NaN         NaN
# 6279.0  11/07/2019           NaN       NaN         NaN
# 6280.0  11/07/2019  25-30/7/2019 -2.840111  114.001722
# 6281.0  11/07/2019  25-30/7/2019 -2.830773  114.005396
# 6282.0  11/07/2019           NaN       NaN         NaN
# 6283.0  11/07/2019           NaN       NaN         NaN
# 6284.0  11/07/2019           NaN       NaN         NaN
# 6287.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
# 6288.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
# 6289.0  11/07/2019  25-30/7/2019 -2.942903  114.077344
# 6290.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
#
#                                         period        end_date  \
# id_grid sat_date
# 1271.0  01/07/2019                         NaN             NaN
# 1272.0  01/07/2019                         NaN             NaN
# 1273.0  01/07/2019                         NaN             NaN
# 1274.0  01/07/2019                         NaN             NaN
# 1278.0  01/07/2019                         NaN             NaN
# 1279.0  01/07/2019                         NaN             NaN
# 1282.0  01/07/2019                         NaN             NaN
# 1307.0  01/07/2019                         NaN             NaN
# 1323.0  01/07/2019                         NaN             NaN
# 1324.0  01/07/2019                         NaN             NaN
# 1336.0  01/07/2019                         NaN             NaN
# 1337.0  01/07/2019                         NaN             NaN
# 1343.0  01/07/2019   0 days 00:00:00.000000000  16/7/2019 0:00
# 1344.0  01/07/2019                         NaN             NaN
# 1345.0  01/07/2019                         NaN             NaN
# 1346.0  01/07/2019                         NaN             NaN
# 1347.0  01/07/2019                         NaN             NaN
# 1348.0  01/07/2019                         NaN             NaN
# 1349.0  01/07/2019                         NaN             NaN
# 1350.0  01/07/2019                         NaN             NaN
# 1351.0  01/07/2019                         NaN             NaN
# 1352.0  01/07/2019                         NaN             NaN
# 1353.0  01/07/2019                         NaN             NaN
# 1354.0  01/07/2019                         NaN             NaN
# 1355.0  01/07/2019                         NaN             NaN
# 1356.0  01/07/2019                         NaN             NaN
# 1357.0  01/07/2019                         NaN             NaN
# 1358.0  01/07/2019                         NaN             NaN
# 1359.0  01/07/2019                         NaN             NaN
# 1360.0  01/07/2019                         NaN             NaN
# ...                                        ...             ...
# 6259.0  11/07/2019                         NaN             NaN
# 6260.0  11/07/2019                         NaN             NaN
# 6261.0  11/07/2019                         NaN             NaN
# 6262.0  11/07/2019                         NaN             NaN
# 6263.0  11/07/2019                         NaN             NaN
# 6264.0  11/07/2019                         NaN             NaN
# 6265.0  11/07/2019                         NaN             NaN
# 6266.0  11/07/2019                         NaN             NaN
# 6267.0  11/07/2019                         NaN             NaN
# 6268.0  11/07/2019                         NaN             NaN
# 6269.0  11/07/2019                         NaN             NaN
# 6270.0  11/07/2019                         NaN             NaN
# 6271.0  11/07/2019                         NaN             NaN
# 6272.0  11/07/2019                         NaN             NaN
# 6273.0  11/07/2019                         NaN             NaN
# 6274.0  11/07/2019                         NaN             NaN
# 6275.0  11/07/2019                         NaN             NaN
# 6276.0  11/07/2019                         NaN             NaN
# 6277.0  11/07/2019                         NaN             NaN
# 6278.0  11/07/2019                         NaN             NaN
# 6279.0  11/07/2019                         NaN             NaN
# 6280.0  11/07/2019   5 days 00:00:00.000000000  30/7/2019 0:00
# 6281.0  11/07/2019   5 days 00:00:00.000000000  30/7/2019 0:00
# 6282.0  11/07/2019                         NaN             NaN
# 6283.0  11/07/2019                         NaN             NaN
# 6284.0  11/07/2019                         NaN             NaN
# 6287.0  11/07/2019  20 days 00:00:00.000000000  25/7/2019 0:00
# 6288.0  11/07/2019  20 days 00:00:00.000000000  25/7/2019 0:00
# 6289.0  11/07/2019   5 days 00:00:00.000000000  30/7/2019 0:00
# 6290.0  11/07/2019  20 days 00:00:00.000000000  25/7/2019 0:00
#
#                         start_date  id_truth    weight  geo_weight  \
# id_grid sat_date
# 1271.0  01/07/2019             NaN       NaN  0.031250    0.000000
# 1272.0  01/07/2019             NaN       NaN  0.031250    0.000000
# 1273.0  01/07/2019             NaN       NaN  0.060000    0.000000
# 1274.0  01/07/2019             NaN       NaN  0.060000    0.000000
# 1278.0  01/07/2019             NaN       NaN  0.031250    0.000000
# 1279.0  01/07/2019             NaN       NaN  0.031250    0.000000
# 1282.0  01/07/2019             NaN       NaN  0.051250    0.000000
# 1307.0  01/07/2019             NaN       NaN  0.071250    0.000000
# 1323.0  01/07/2019             NaN       NaN  0.066250    0.000000
# 1324.0  01/07/2019             NaN       NaN  0.066250    0.000000
# 1336.0  01/07/2019             NaN       NaN  0.066250    0.000000
# 1337.0  01/07/2019             NaN       NaN  0.066250    0.000000
# 1343.0  01/07/2019  16/7/2019 0:00     169.0  0.085000    0.000000
# 1344.0  01/07/2019             NaN       NaN  0.033750    0.000000
# 1345.0  01/07/2019             NaN       NaN  0.158750    0.000000
# 6270.0  11/07/2019  POLYGON ((12701976.873 -307195.474, 12703976.8...
# 6271.0  11/07/2019  POLYGON ((12697976.873 -309195.474, 12699976.8...
# 6272.0  11/07/2019  POLYGON ((12699976.873 -309195.474, 12701976.8...
# 6273.0  11/07/2019  POLYGON ((12701976.873 -309195.474, 12703976.8...
# 6274.0  11/07/2019  POLYGON ((12689976.873 -311195.474, 12691976.8...
# 6275.0  11/07/2019  POLYGON ((12691976.873 -311195.474, 12693976.8...
# 6276.0  11/07/2019  POLYGON ((12693976.873 -311195.474, 12695976.8...
# 6277.0  11/07/2019  POLYGON ((12695976.873 -311195.474, 12697976.8...
# 6278.0  11/07/2019  POLYGON ((12697976.873 -311195.474, 12699976.8...
# 6279.0  11/07/2019  POLYGON ((12699976.873 -311195.474, 12701976.8...
# 6280.0  11/07/2019  POLYGON ((12689976.873 -313195.474, 12691976.8...
# 6281.0  11/07/2019  POLYGON ((12691976.873 -314091.318, 12692083.3...
# 6282.0  11/07/2019  POLYGON ((12693976.873 -313195.474, 12695976.8...
# 6283.0  11/07/2019  POLYGON ((12695976.873 -313195.474, 12697976.8...
# 6284.0  11/07/2019  POLYGON ((12697976.873 -313195.474, 12699976.8...
# 6287.0  11/07/2019  POLYGON ((12698641.328 -329193.301, 12698639.3...
# 6288.0  11/07/2019  POLYGON ((12700425.793 -327195.474, 12701976.8...
# 6289.0  11/07/2019  POLYGON ((12697976.873 -329195.474, 12698639.3...
# 6290.0  11/07/2019  POLYGON ((12700855.633 -329195.474, 12701976.8...
#
# [5132 rows x 12 columns]

# %%
overlaid_gdf.loc[overlaid_gdf['adj_weight'].isna(), 'adj_weight'] = 0
overlaid_gdf.loc[overlaid_gdf['polar_weight'].isna(), 'polar_weight'] = 0
overlaid_gdf.loc[overlaid_gdf['geo_weight'].isna(), 'geo_weight'] = 0

# %%
overlaid_gdf = overlaid_gdf.reset_index()
overlaid_gdf = geopandas.GeoDataFrame(overlaid_gdf)

# %%
overlaid_gdf.loc[overlaid_gdf['lat'].isna(), 'truth_flag'] = 0
overlaid_gdf['start_date'].unique()
# Out:
# array([nan, '16/7/2019 0:00', '1/7/2019 0:00', '31/7/2019 0:00',
#        '25/7/2019 0:00', '20/7/2019 0:00', '28/7/2019 0:00',
#        '30/7/2019 0:00', '5/7/2019 0:00', '10/7/2019 0:00'], dtype=object)

# %%
for index, row in overlaid_gdf.iterrows():
    if pd.isna(row['start_date']):
        pass
    else:
        sat_date =  datetime.strptime(row['sat_date'], "%d/%m/%Y")
        truth_start_date = datetime.strptime(row['start_date'], "%d/%m/%Y %H:%M")
        truth_end_date = datetime.strptime(row['end_date'], "%d/%m/%Y %H:%M")
        if (sat_date >= truth_start_date) and (sat_date <= truth_end_date):
            overlaid_gdf.loc[index, 'truth_flag'] = 1
        else:
            overlaid_gdf.loc[index, 'truth_flag'] = 0 #np.nan

# %%
overlaid_gdf['adj_weight'].hist(bins=30)

# %%
overlaid_gdf['truth_flag'].hist()
#overlaid_gdf.to_file('test.geojson', driver='GeoJSON')

# %%
final_gdf = overlaid_gdf.dropna(axis=0, subset=['truth_flag'])

# %%
final_gdf
# Out:
#       id_grid    sat_date     datestamp       lat         lon  \
# 0      1271.0  01/07/2019           NaN       NaN         NaN
# 1      1272.0  01/07/2019           NaN       NaN         NaN
# 2      1273.0  01/07/2019           NaN       NaN         NaN
# 3      1274.0  01/07/2019           NaN       NaN         NaN
# 4      1278.0  01/07/2019           NaN       NaN         NaN
# 5      1279.0  01/07/2019           NaN       NaN         NaN
# 6      1282.0  01/07/2019           NaN       NaN         NaN
# 7      1307.0  01/07/2019           NaN       NaN         NaN
# 8      1323.0  01/07/2019           NaN       NaN         NaN
# 9      1324.0  01/07/2019           NaN       NaN         NaN
# 10     1336.0  01/07/2019           NaN       NaN         NaN
# 11     1337.0  01/07/2019           NaN       NaN         NaN
# 12     1343.0  01/07/2019     16/7/2019  0.164093  109.250019
# 13     1344.0  01/07/2019           NaN       NaN         NaN
# 14     1345.0  01/07/2019           NaN       NaN         NaN
# 15     1346.0  01/07/2019           NaN       NaN         NaN
# 16     1347.0  01/07/2019           NaN       NaN         NaN
# 17     1348.0  01/07/2019           NaN       NaN         NaN
# 18     1349.0  01/07/2019           NaN       NaN         NaN
# 19     1350.0  01/07/2019           NaN       NaN         NaN
# 20     1351.0  01/07/2019           NaN       NaN         NaN
# 21     1352.0  01/07/2019           NaN       NaN         NaN
# 22     1353.0  01/07/2019           NaN       NaN         NaN
# 23     1354.0  01/07/2019           NaN       NaN         NaN
# 24     1355.0  01/07/2019           NaN       NaN         NaN
# 25     1356.0  01/07/2019           NaN       NaN         NaN
# 26     1357.0  01/07/2019           NaN       NaN         NaN
# 27     1358.0  01/07/2019           NaN       NaN         NaN
# 28     1359.0  01/07/2019           NaN       NaN         NaN
# 29     1360.0  01/07/2019           NaN       NaN         NaN
# ...       ...         ...           ...       ...         ...
# 5102   6259.0  11/07/2019           NaN       NaN         NaN
# 5103   6260.0  11/07/2019           NaN       NaN         NaN
# 5104   6261.0  11/07/2019           NaN       NaN         NaN
# 5105   6262.0  11/07/2019           NaN       NaN         NaN
# 5106   6263.0  11/07/2019           NaN       NaN         NaN
# 5107   6264.0  11/07/2019           NaN       NaN         NaN
# 5108   6265.0  11/07/2019           NaN       NaN         NaN
# 5109   6266.0  11/07/2019           NaN       NaN         NaN
# 5110   6267.0  11/07/2019           NaN       NaN         NaN
# 5111   6268.0  11/07/2019           NaN       NaN         NaN
# 5112   6269.0  11/07/2019           NaN       NaN         NaN
# 5113   6270.0  11/07/2019           NaN       NaN         NaN
# 5114   6271.0  11/07/2019           NaN       NaN         NaN
# 5115   6272.0  11/07/2019           NaN       NaN         NaN
# 5116   6273.0  11/07/2019           NaN       NaN         NaN
# 5117   6274.0  11/07/2019           NaN       NaN         NaN
# 5118   6275.0  11/07/2019           NaN       NaN         NaN
# 5119   6276.0  11/07/2019           NaN       NaN         NaN
# 5120   6277.0  11/07/2019           NaN       NaN         NaN
# 5121   6278.0  11/07/2019           NaN       NaN         NaN
# 5122   6279.0  11/07/2019           NaN       NaN         NaN
# 5123   6280.0  11/07/2019  25-30/7/2019 -2.840111  114.001722
# 5124   6281.0  11/07/2019  25-30/7/2019 -2.830773  114.005396
# 5125   6282.0  11/07/2019           NaN       NaN         NaN
# 5126   6283.0  11/07/2019           NaN       NaN         NaN
# 5127   6284.0  11/07/2019           NaN       NaN         NaN
# 5128   6287.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
# 5129   6288.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
# 5130   6289.0  11/07/2019  25-30/7/2019 -2.942903  114.077344
# 5131   6290.0  11/07/2019   5-25/7/2019 -2.964947  114.083773
#
#                           period        end_date      start_date  id_truth  \
# 0                            NaN             NaN             NaN       NaN
# 1                            NaN             NaN             NaN       NaN
# 2                            NaN             NaN             NaN       NaN
# 3                            NaN             NaN             NaN       NaN
# 4                            NaN             NaN             NaN       NaN
# 5                            NaN             NaN             NaN       NaN
# 6                            NaN             NaN             NaN       NaN
# 7                            NaN             NaN             NaN       NaN
# 8                            NaN             NaN             NaN       NaN
# 9                            NaN             NaN             NaN       NaN
# 10                           NaN             NaN             NaN       NaN
# 11                           NaN             NaN             NaN       NaN
# 12     0 days 00:00:00.000000000  16/7/2019 0:00  16/7/2019 0:00     169.0
# 13                           NaN             NaN             NaN       NaN
# 14                           NaN             NaN             NaN       NaN
# 15                           NaN             NaN             NaN       NaN
# 16                           NaN             NaN             NaN       NaN
# 17                           NaN             NaN             NaN       NaN
# 18                           NaN             NaN             NaN       NaN
# 19                           NaN             NaN             NaN       NaN
# 20                           NaN             NaN             NaN       NaN
# 21                           NaN             NaN             NaN       NaN
# 22                           NaN             NaN             NaN       NaN
# 23                           NaN             NaN             NaN       NaN
# 24                           NaN             NaN             NaN       NaN
# 25                           NaN             NaN             NaN       NaN
# 26                           NaN             NaN             NaN       NaN
# 27                           NaN             NaN             NaN       NaN
# 28                           NaN             NaN             NaN       NaN
# 29                           NaN             NaN             NaN       NaN
# ...                          ...             ...             ...       ...
# 5102                         NaN             NaN             NaN       NaN
# 5103                         NaN             NaN             NaN       NaN
# 5104                         NaN             NaN             NaN       NaN
# 5105                         NaN             NaN             NaN       NaN
# 5106                         NaN             NaN             NaN       NaN
# 5107                         NaN             NaN             NaN       NaN
# 5108                         NaN             NaN             NaN       NaN
# 5109                         NaN             NaN             NaN       NaN
# 5110                         NaN             NaN             NaN       NaN
# 5111                         NaN             NaN             NaN       NaN
# 5112                         NaN             NaN             NaN       NaN
# 5113                         NaN             NaN             NaN       NaN
# 5114                         NaN             NaN             NaN       NaN
# 5115                         NaN             NaN             NaN       NaN
# 5116                         NaN             NaN             NaN       NaN
# 5117                         NaN             NaN             NaN       NaN
# 5118                         NaN             NaN             NaN       NaN
# 5119                         NaN             NaN             NaN       NaN
# 5120                         NaN             NaN             NaN       NaN
# 5121                         NaN             NaN             NaN       NaN
# 5122                         NaN             NaN             NaN       NaN
# 5123   5 days 00:00:00.000000000  30/7/2019 0:00  25/7/2019 0:00     230.0
# 5124   5 days 00:00:00.000000000  30/7/2019 0:00  25/7/2019 0:00     229.0
# 5125                         NaN             NaN             NaN       NaN
# 5110  POLYGON ((12699976.873 -303195.474, 12701976.8...         0.0
# 5111  POLYGON ((12701976.873 -303195.474, 12703976.8...         0.0
# 5112  POLYGON ((12699976.873 -307195.474, 12701976.8...         0.0
# 5113  POLYGON ((12701976.873 -307195.474, 12703976.8...         0.0
# 5114  POLYGON ((12697976.873 -309195.474, 12699976.8...         0.0
# 5115  POLYGON ((12699976.873 -309195.474, 12701976.8...         0.0
# 5116  POLYGON ((12701976.873 -309195.474, 12703976.8...         0.0
# 5117  POLYGON ((12689976.873 -311195.474, 12691976.8...         0.0
# 5118  POLYGON ((12691976.873 -311195.474, 12693976.8...         0.0
# 5119  POLYGON ((12693976.873 -311195.474, 12695976.8...         0.0
# 5120  POLYGON ((12695976.873 -311195.474, 12697976.8...         0.0
# 5121  POLYGON ((12697976.873 -311195.474, 12699976.8...         0.0
# 5122  POLYGON ((12699976.873 -311195.474, 12701976.8...         0.0
# 5123  POLYGON ((12689976.873 -313195.474, 12691976.8...         0.0
# 5124  POLYGON ((12691976.873 -314091.318, 12692083.3...         0.0
# 5125  POLYGON ((12693976.873 -313195.474, 12695976.8...         0.0
# 5126  POLYGON ((12695976.873 -313195.474, 12697976.8...         0.0
# 5127  POLYGON ((12697976.873 -313195.474, 12699976.8...         0.0
# 5128  POLYGON ((12698641.328 -329193.301, 12698639.3...         1.0
# 5129  POLYGON ((12700425.793 -327195.474, 12701976.8...         1.0
# 5130  POLYGON ((12697976.873 -329195.474, 12698639.3...         0.0
# 5131  POLYGON ((12700855.633 -329195.474, 12701976.8...         1.0
#
# [5132 rows x 15 columns]

# %%
from sklearn import metrics
y = final_gdf['truth_flag'].values.astype(int)
scores = final_gdf['adj_weight'].values.astype(float)
scores_geo = final_gdf['geo_weight'].values.astype(float)
scores_polar = final_gdf['polar_weight'].values.astype(float)
#alpha = 0.5
#gamma = 2
#scores = (scores_geo * (1 - alpha) + scores_polar * alpha) ** (1/gamma)
fpr, tpr, thresholds = metrics.roc_curve(y, scores, pos_label=1)

# %%
print (fpr, tpr, thresholds)
# Out:
# [0.         0.00676247 0.00972105 0.00972105 0.00993238 0.00993238
#  0.01310228 0.01352494 0.01373626 0.01373626 0.01458157 0.01458157
#  0.0147929  0.0147929  0.01500423 0.01500423 0.01542688 0.01669484
#  0.0171175  0.01775148 0.01775148 0.01817413 0.01817413 0.01923077
#  0.01923077 0.02430262 0.02472527 0.0272612  0.0272612  0.02789518
#  0.02789518 0.02895182 0.02916314 0.03064243 0.03064243 0.03106509
#  0.03529163 0.03529163 0.03571429 0.03592561 0.03592561 0.03613694
#  0.03613694 0.03634827 0.03634827 0.03867287 0.03867287 0.0397295
#  0.04036348 0.04099746 0.04099746 0.04120879 0.04142012 0.04268808
#  0.04268808 0.04332206 0.04332206 0.04374472 0.04374472 0.04416737
#  0.04416737 0.04459003 0.04543533 0.04543533 0.04585799 0.04585799
#  0.04628064 0.04712595 0.04754861 0.04818259 0.04860524 0.0498732
#  0.05092984 0.05092984 0.05156382 0.05240913 0.05304311 0.05304311
#  0.05325444 0.05367709 0.05388842 0.05388842 0.05431107 0.05515638
#  0.34612703 0.34594996 0.34460122 0.34299717 0.34278273 0.34221023
#  0.34192362 0.34077478 0.3401989  0.3391165  0.3385378  0.33639525
#  0.3335416  0.33306362 0.33265863 0.33166248 0.32947522 0.32917753
#  0.32839479 0.32828282 0.32787193 0.32757277 0.32596012 0.32565921
#  0.32535802 0.32475481 0.32403703 0.32343136 0.32210247 0.32088267
#  0.32015621 0.31984984 0.31819805 0.31788979 0.31622777 0.31591759
#  0.3156071  0.31424513 0.31362054 0.31311215 0.3122499  0.31173927
#  0.31024184 0.30929236 0.3082207  0.30790245 0.30758388 0.30618622
#  0.30586586 0.30554516 0.30522412 0.30413813 0.30349274 0.30207615
#  0.30175142 0.3        0.29967302 0.29934569 0.29790938 0.29704426
#  0.29580399 0.29559677 0.29547237 0.2936835  0.29334949 0.29154759
#  0.29053703 0.28939592 0.28837782 0.28722813 0.2868866  0.28585956
#  0.28504386 0.28435514 0.28284271 0.28180093 0.2806243  0.28005602
#  0.27922336 0.27838822 0.27768299 0.2773297  0.27662178 0.27613403
#  0.27542303 0.27386128 0.27156951 0.26925824 0.26889389 0.26692696
#  0.26619137 0.26457513 0.26420432 0.26220221 0.26196842 0.25980762
#  0.25942999 0.25739075 0.25700957 0.25495098 0.25248762 0.25
#  0.24960754 0.24748737 0.24494897 0.24414718 0.24253563 0.24238399
#  0.24197918 0.23979158 0.23815055 0.23717082 0.23634264 0.23452079
#  0.23184046 0.22912878 0.22912878 0.22638463 0.2236068  0.22140372
#  0.22079402 0.21794495 0.21505813 0.20916501 0.20615528 0.20310096
#  0.2        0.19802951 0.1968502  0.19364917 0.19263396 0.19039433
#  0.18708287 0.18371173 0.18027756 0.1767767  0.17320508 0.17149859
#  0.16955825 0.16583124 0.16201852 0.15411035 0.15       0.1457738
#  0.14142136 0.14002801 0.13693064 0.12747549 0.11726039 0.1
#  0.09901475 0.        ]

# %%
metrics.roc_auc_score(y, scores)
# Out:
# 0.6493168850380389

# %%
csi = 1/((1/(1-fpr)) + (1/tpr) - 1)
csi.argmax()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# 405

# %%
csi[csi.argmax()], tpr[csi.argmax()], fpr[csi.argmax()]
# Out:
# (0.46466361346434243, 0.6675, 0.39539306846999156)

# %%
thresholds[csi.argmax()]
# Out:
# 0.23717082451262844

# %%
csi.max()
# Out:
# 0.46466361346434243

# %%
csi.shape, fpr.shape, tpr.shape
# Out:
# ((446,), (446,), (446,))

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes()

ax.plot(thresholds[1:-1], tpr[1:-1], label='POD');
ax.plot(thresholds[1:-1], fpr[1:-1], label='FAR');
ax.plot(thresholds[1:-1], csi[1:-1], label='CSI');
ax.legend()
ax.set_xlabel('Threshold')
ax.set_ylabel('Skill Score/POD/FAR')
plt.xticks(np.arange(0, 1, step=0.1))
plt.title('Verification scores for MultiSat (H-8/MODIS/VIIRS)(Jul 2019)')
# Out:
# Text(0.5, 1.0, 'Verification scores for MultiSat (H-8/MODIS/VIIRS)(Jul 2019)')

# %%
import numpy as np
alpha_list = np.linspace(0, 1.0, 50)
scores_alpha_list = []
y = final_gdf['truth_flag'].values.astype(int)
fpr_alpha_list = []
tpr_alpha_list = []
thresholds_alpha_list = []
for alpha in alpha_list:
    score_alpha = ((1 - alpha) * final_gdf['geo_weight'].values.astype(float)) + (alpha * final_gdf['polar_weight'].values.astype(float))
    score_alpha = (score_alpha) ** (1/2)
    roc_alpha = metrics.roc_auc_score(y, score_alpha)
    scores_alpha_list.append(roc_alpha)
    fpr_alpha, tpr_alpha, thresholds_alpha = metrics.roc_curve(y, score_alpha, pos_label=1)
    fpr_alpha_list.append(fpr_alpha)
    tpr_alpha_list.append(tpr_alpha)
    thresholds_alpha_list.append(thresholds_alpha)

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes()

print (alpha_list[np.argmax(scores_alpha_list)], np.max(scores_alpha_list))

ax.plot(alpha_list, scores_alpha_list, label='alpha');
ax.legend()
plt.title('Alpha vs ROC score')
ax.set_xlabel('Alpha')
ax.set_ylabel('ROC score (1.0 is perfect)')
# Out:
# 0.8163265306122448 0.657812235841082
# Text(0, 0.5, 'ROC score (1.0 is perfect)')

# %%
from sklearn.utils import resample

# Separate majority and minority classes
df_majority = final_gdf[final_gdf.truth_flag==0]
df_minority = final_gdf[final_gdf.truth_flag==1]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=len(df_minority),     # to match minority class
                                 random_state=123) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
y_downsampled = df_downsampled['truth_flag'].values.astype(int)
scores_downsampled = df_downsampled['adj_weight'].values.astype(float)
scores_geo_downsampled = df_downsampled['geo_weight'].values.astype(float)
scores_polar_downsampled = df_downsampled['polar_weight'].values.astype(float)
fpr_downsampled, tpr_downsampled, thresholds_downsampled = metrics.roc_curve(y_downsampled, scores_downsampled, pos_label=1)

# %%
metrics.roc_auc_score(y_downsampled, scores_downsampled)
csi_downsampled = 1/((1/(1-fpr_downsampled)) + (1/tpr_downsampled) - 1)
csi_downsampled.max()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# 0.481217731885348

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes()

ax.plot(thresholds_downsampled[1:-2], tpr_downsampled[1:-2], label='POD');
ax.plot(thresholds_downsampled[1:-2], fpr_downsampled[1:-2], label='FAR');
ax.plot(thresholds_downsampled[1:-2], csi_downsampled[1:-2], label='CSI');
ax.legend()
ax.set_xlabel('Threshold')
ax.set_ylabel('Skill Score/POD/FAR')
plt.xticks(np.arange(0, 1, step=0.1))
plt.title('Verification scores for MultiSat (H-8/MODIS/VIIRS)(Downsampled)')
# Out:
# Text(0.5, 1.0, 'Verification scores for MultiSat (H-8/MODIS/VIIRS)(Downsampled)')

# %%
pdf = pd.DataFrame(df_downsampled)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(fit_intercept=True, penalty='none', solver='newton-cg')

# %%
from sklearn.model_selection import train_test_split

pdf['adj_weight'] = (0.5 * pdf['geo_weight'] + 0.5 * pdf['polar_weight']) ** (1/3)
pdf.plot.scatter(x='adj_weight', y='truth_flag')
x = pdf[['adj_weight']].values.reshape(-1,1)
y = pdf['truth_flag'].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=2)

# %%
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='none',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logisticRegr.predict(x_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logisticRegr.score(x, y)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[71 30]
#  [34 65]]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
csi = 1/((1/(1-fpr)) + (1/tpr) - 1)
print (csi.max(), logit_roc_auc)
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
# Out:
# 0.5139770575787949 0.6797679767976798
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
print (logisticRegr.coef_)
# Out:
# [[3.42185933]]

# %%
prob_y = logisticRegr.predict_proba(x)

# %%
prob_y[:, 1]
# Out:
# array([0.40963124, 0.49318224, 0.53529026, 0.53854163, 0.47359765,
#        0.52110441, 0.62383326, 0.37365301, 0.58135495, 0.37365301,
#        0.80930398, 0.37365301, 0.60480523, 0.37365301, 0.49677485,
#        0.55797363, 0.37365301, 0.45632846, 0.37365301, 0.55797363,
#        0.67802367, 0.63963135, 0.37365301, 0.75421092, 0.49853615,
#        0.5624213 , 0.52087046, 0.37365301, 0.46929718, 0.64477079,
#        0.40963124, 0.47359765, 0.60480523, 0.68278901, 0.52978018,
#        0.37365301, 0.37365301, 0.37365301, 0.54060209, 0.53854163,
#        0.37365301, 0.37365301, 0.37365301, 0.37365301, 0.68710132,
#        0.40963124, 0.37365301, 0.51187169, 0.47978758, 0.63526397,
#        0.62008528, 0.42136402, 0.48960125, 0.37365301, 0.37365301,
#        0.45215436, 0.40963124, 0.53929185, 0.37365301, 0.48569515,
#        0.6786643 , 0.45632846, 0.43548513, 0.50027505, 0.37365301,
#        0.37365301, 0.47775724, 0.45632846, 0.63857468, 0.49499046,
#        0.68168363, 0.37365301, 0.52110441, 0.40963124, 0.37365301,
#        0.5255071 , 0.37365301, 0.55996638, 0.45632846, 0.57331672,
#        0.40963124, 0.37365301, 0.37365301, 0.37365301, 0.45632846,
#        0.37365301, 0.45632846, 0.43548513, 0.37365301, 0.37365301,
#        0.80298046, 0.45632846, 0.37365301, 0.69827503, 0.50352288,
#        0.40963124, 0.37365301, 0.48569515, 0.37365301, 0.64080156,
#        0.47569436, 0.37365301, 0.37365301, 0.37365301, 0.37365301,
#        0.51656277, 0.79837007, 0.50536376, 0.37365301, 0.37365301,
#        0.61774312, 0.69024872, 0.37365301, 0.37365301, 0.40963124,
#        0.37365301, 0.37365301, 0.53117719, 0.37365301, 0.37365301,
#        0.37365301, 0.37365301, 0.40963124, 0.37365301, 0.50352288,
#        0.40963124, 0.53507801, 0.65942062, 0.46484362, 0.47359765,
#        0.64080156, 0.40963124, 0.4817866 , 0.37365301, 0.60694824,
#        0.52694543, 0.37365301, 0.40963124, 0.48960125, 0.37365301,
#        0.40963124, 0.52978018, 0.52978018, 0.37365301, 0.37365301,
#        0.66088748, 0.40963124, 0.45632846, 0.37365301, 0.60475465,
#        0.40963124, 0.40963124, 0.37365301, 0.37365301, 0.70190635,
#        0.37365301, 0.37365301, 0.40963124, 0.40963124, 0.48949122,
