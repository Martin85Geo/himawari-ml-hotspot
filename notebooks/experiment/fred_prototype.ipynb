# %%
import pandas as pd
from asmclib import geohotspot
from datetime import datetime, timedelta

# %%
file = r"C:\Users\Wong Songhan\Desktop\Project FRED\hotspots\db\JP1_LATE.txt"

# %%
geo_hs = geohotspot.GeoHotspot()

# %%
geo_hs.get_hs_from_csv_db(file, 'JP1_LATE', datetime(2019, 1, 2), datetime(2019, 1, 3))

# %%
geo_hs.hs_df
# Out:
#     satellite                date    lat     lon     FRP  confidence daynight
# 0    JP1_LATE 2019-01-02 04:38:01 -14.27  127.49   77.05          99      day
# 1    JP1_LATE 2019-01-02 04:38:01 -14.27  127.49   61.83          97      day
# 2    JP1_LATE 2019-01-02 04:38:01 -14.21  127.45    8.35          60      day
# 3    JP1_LATE 2019-01-02 04:38:01 -14.21  127.44   11.56          81      day
# 4    JP1_LATE 2019-01-02 04:38:01 -14.07  127.46   17.41          29      day
# 5    JP1_LATE 2019-01-02 04:42:02   0.64  128.20    3.01          45      day
# 6    JP1_LATE 2019-01-02 04:42:02   1.49  127.63    9.27           0      day
# 7    JP1_LATE 2019-01-02 04:43:05   2.78  125.40   47.26          78      day
# 8    JP1_LATE 2019-01-02 04:43:05   6.02  125.47    4.63           0      day
# 9    JP1_LATE 2019-01-02 04:43:05   6.04  124.99    6.92          65      day
# 10   JP1_LATE 2019-01-02 04:43:05   6.04  124.96    6.99          66      day
# ...
